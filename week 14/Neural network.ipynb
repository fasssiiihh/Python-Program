# %%
import csv
import numpy as np
from tensorflow import keras as kr

# Load the Iris dataset.
iris = list(csv.reader(open('iris.csv')))[1:]

# %%
iris
# Out:
# [['5.1', '3.5', '1.4', '0.2', 'setosa'],
#  ['4.9', '3.0', '1.4', '0.2', 'setosa'],
#  ['4.7', '3.2', '1.3', '0.2', 'setosa'],
#  ['4.6', '3.1', '1.5', '0.2', 'setosa'],
#  ['5.0', '3.6', '1.4', '0.2', 'setosa'],
#  ['5.4', '3.9', '1.7', '0.4', 'setosa'],
#  ['4.6', '3.4', '1.4', '0.3', 'setosa'],
#  ['5.0', '3.4', '1.5', '0.2', 'setosa'],
#  ['4.4', '2.9', '1.4', '0.2', 'setosa'],
#  ['4.9', '3.1', '1.5', '0.1', 'setosa'],
#  ['5.4', '3.7', '1.5', '0.2', 'setosa'],
#  ['4.8', '3.4', '1.6', '0.2', 'setosa'],
#  ['4.8', '3.0', '1.4', '0.1', 'setosa'],
#  ['4.3', '3.0', '1.1', '0.1', 'setosa'],
#  ['5.8', '4.0', '1.2', '0.2', 'setosa'],
#  ['5.7', '4.4', '1.5', '0.4', 'setosa'],
#  ['5.4', '3.9', '1.3', '0.4', 'setosa'],
#  ['5.1', '3.5', '1.4', '0.3', 'setosa'],
#  ['5.7', '3.8', '1.7', '0.3', 'setosa'],
#  ['5.1', '3.8', '1.5', '0.3', 'setosa'],
#  ['5.4', '3.4', '1.7', '0.2', 'setosa'],
#  ['5.1', '3.7', '1.5', '0.4', 'setosa'],
#  ['4.6', '3.6', '1.0', '0.2', 'setosa'],
#  ['5.1', '3.3', '1.7', '0.5', 'setosa'],
#  ['4.8', '3.4', '1.9', '0.2', 'setosa'],
#  ['5.0', '3.0', '1.6', '0.2', 'setosa'],
#  ['5.0', '3.4', '1.6', '0.4', 'setosa'],
#  ['5.2', '3.5', '1.5', '0.2', 'setosa'],
#  ['5.2', '3.4', '1.4', '0.2', 'setosa'],
#  ['4.7', '3.2', '1.6', '0.2', 'setosa'],
#  ['4.8', '3.1', '1.6', '0.2', 'setosa'],
#  ['5.4', '3.4', '1.5', '0.4', 'setosa'],
#  ['5.2', '4.1', '1.5', '0.1', 'setosa'],
#  ['5.5', '4.2', '1.4', '0.2', 'setosa'],
#  ['4.9', '3.1', '1.5', '0.1', 'setosa'],
#  ['5.0', '3.2', '1.2', '0.2', 'setosa'],
#  ['5.5', '3.5', '1.3', '0.2', 'setosa'],
#  ['4.9', '3.1', '1.5', '0.1', 'setosa'],
#  ['4.4', '3.0', '1.3', '0.2', 'setosa'],
#  ['5.1', '3.4', '1.5', '0.2', 'setosa'],
#  ['5.0', '3.5', '1.3', '0.3', 'setosa'],
#  ['4.5', '2.3', '1.3', '0.3', 'setosa'],
#  ['4.4', '3.2', '1.3', '0.2', 'setosa'],
#  ['5.0', '3.5', '1.6', '0.6', 'setosa'],
#  ['5.1', '3.8', '1.9', '0.4', 'setosa'],
#  ['4.8', '3.0', '1.4', '0.3', 'setosa'],
#  ['5.1', '3.8', '1.6', '0.2', 'setosa'],
#  ['4.6', '3.2', '1.4', '0.2', 'setosa'],
#  ['5.3', '3.7', '1.5', '0.2', 'setosa'],
#  ['5.0', '3.3', '1.4', '0.2', 'setosa'],
#  ['7.0', '3.2', '4.7', '1.4', 'versicolor'],
#  ['6.4', '3.2', '4.5', '1.5', 'versicolor'],
#  ['6.9', '3.1', '4.9', '1.5', 'versicolor'],
#  ['5.5', '2.3', '4.0', '1.3', 'versicolor'],
#  ['6.5', '2.8', '4.6', '1.5', 'versicolor'],
#  ['5.7', '2.8', '4.5', '1.3', 'versicolor'],
#  ['6.3', '3.3', '4.7', '1.6', 'versicolor'],
#  ['4.9', '2.4', '3.3', '1.0', 'versicolor'],
#  ['6.6', '2.9', '4.6', '1.3', 'versicolor'],
#  ['5.2', '2.7', '3.9', '1.4', 'versicolor'],
#  ['5.0', '2.0', '3.5', '1.0', 'versicolor'],
#  ['5.9', '3.0', '4.2', '1.5', 'versicolor'],
#  ['6.0', '2.2', '4.0', '1.0', 'versicolor'],
#  ['6.1', '2.9', '4.7', '1.4', 'versicolor'],
#  ['5.6', '2.9', '3.6', '1.3', 'versicolor'],
#  ['6.7', '3.1', '4.4', '1.4', 'versicolor'],
#  ['5.6', '3.0', '4.5', '1.5', 'versicolor'],
#  ['5.8', '2.7', '4.1', '1.0', 'versicolor'],
#  ['6.2', '2.2', '4.5', '1.5', 'versicolor'],
#  ['5.6', '2.5', '3.9', '1.1', 'versicolor'],
#  ['5.9', '3.2', '4.8', '1.8', 'versicolor'],
#  ['6.1', '2.8', '4.0', '1.3', 'versicolor'],
#  ['6.3', '2.5', '4.9', '1.5', 'versicolor'],
#  ['6.1', '2.8', '4.7', '1.2', 'versicolor'],
#  ['6.4', '2.9', '4.3', '1.3', 'versicolor'],
#  ['6.6', '3.0', '4.4', '1.4', 'versicolor'],
#  ['6.8', '2.8', '4.8', '1.4', 'versicolor'],
#  ['6.7', '3.0', '5.0', '1.7', 'versicolor'],
#  ['6.0', '2.9', '4.5', '1.5', 'versicolor'],
#  ['5.7', '2.6', '3.5', '1.0', 'versicolor'],
#  ['5.5', '2.4', '3.8', '1.1', 'versicolor'],
#  ['5.5', '2.4', '3.7', '1.0', 'versicolor'],
#  ['5.8', '2.7', '3.9', '1.2', 'versicolor'],
#  ['6.0', '2.7', '5.1', '1.6', 'versicolor'],
#  ['5.4', '3.0', '4.5', '1.5', 'versicolor'],
#  ['6.0', '3.4', '4.5', '1.6', 'versicolor'],
#  ['6.7', '3.1', '4.7', '1.5', 'versicolor'],
#  ['6.3', '2.3', '4.4', '1.3', 'versicolor'],
#  ['5.6', '3.0', '4.1', '1.3', 'versicolor'],
#  ['5.5', '2.5', '4.0', '1.3', 'versicolor'],
#  ['5.5', '2.6', '4.4', '1.2', 'versicolor'],
#  ['6.1', '3.0', '4.6', '1.4', 'versicolor'],
#  ['5.8', '2.6', '4.0', '1.2', 'versicolor'],
#  ['5.0', '2.3', '3.3', '1.0', 'versicolor'],
#  ['5.6', '2.7', '4.2', '1.3', 'versicolor'],
#  ['5.7', '3.0', '4.2', '1.2', 'versicolor'],
#  ['5.7', '2.9', '4.2', '1.3', 'versicolor'],
#  ['6.2', '2.9', '4.3', '1.3', 'versicolor'],
#  ['5.1', '2.5', '3.0', '1.1', 'versicolor'],
#  ['5.7', '2.8', '4.1', '1.3', 'versicolor'],
#  ['6.3', '3.3', '6.0', '2.5', 'virginica'],
#  ['5.8', '2.7', '5.1', '1.9', 'virginica'],
#  ['7.1', '3.0', '5.9', '2.1', 'virginica'],
#  ['6.3', '2.9', '5.6', '1.8', 'virginica'],
#  ['6.5', '3.0', '5.8', '2.2', 'virginica'],
#  ['7.6', '3.0', '6.6', '2.1', 'virginica'],
#  ['4.9', '2.5', '4.5', '1.7', 'virginica'],
#  ['7.3', '2.9', '6.3', '1.8', 'virginica'],
#  ['6.7', '2.5', '5.8', '1.8', 'virginica'],
#  ['7.2', '3.6', '6.1', '2.5', 'virginica'],
#  ['6.5', '3.2', '5.1', '2.0', 'virginica'],
#  ['6.4', '2.7', '5.3', '1.9', 'virginica'],
#  ['6.8', '3.0', '5.5', '2.1', 'virginica'],
#  ['5.7', '2.5', '5.0', '2.0', 'virginica'],
#  ['5.8', '2.8', '5.1', '2.4', 'virginica'],
#  ['6.4', '3.2', '5.3', '2.3', 'virginica'],
#  ['6.5', '3.0', '5.5', '1.8', 'virginica'],
#  ['7.7', '3.8', '6.7', '2.2', 'virginica'],
#  ['7.7', '2.6', '6.9', '2.3', 'virginica'],
#  ['6.0', '2.2', '5.0', '1.5', 'virginica'],
#  ['6.9', '3.2', '5.7', '2.3', 'virginica'],
#  ['5.6', '2.8', '4.9', '2.0', 'virginica'],
#  ['7.7', '2.8', '6.7', '2.0', 'virginica'],
#  ['6.3', '2.7', '4.9', '1.8', 'virginica'],
#  ['6.7', '3.3', '5.7', '2.1', 'virginica'],
#  ['7.2', '3.2', '6.0', '1.8', 'virginica'],
#  ['6.2', '2.8', '4.8', '1.8', 'virginica'],
#  ['6.1', '3.0', '4.9', '1.8', 'virginica'],
#  ['6.4', '2.8', '5.6', '2.1', 'virginica'],
#  ['7.2', '3.0', '5.8', '1.6', 'virginica'],
#  ['7.4', '2.8', '6.1', '1.9', 'virginica'],
#  ['7.9', '3.8', '6.4', '2.0', 'virginica'],
#  ['6.4', '2.8', '5.6', '2.2', 'virginica'],
#  ['6.3', '2.8', '5.1', '1.5', 'virginica'],
#  ['6.1', '2.6', '5.6', '1.4', 'virginica'],
#  ['7.7', '3.0', '6.1', '2.3', 'virginica'],
#  ['6.3', '3.4', '5.6', '2.4', 'virginica'],
#  ['6.4', '3.1', '5.5', '1.8', 'virginica'],
#  ['6.0', '3.0', '4.8', '1.8', 'virginica'],
#  ['6.9', '3.1', '5.4', '2.1', 'virginica'],
#  ['6.7', '3.1', '5.6', '2.4', 'virginica'],
#  ['6.9', '3.1', '5.1', '2.3', 'virginica'],
#  ['5.8', '2.7', '5.1', '1.9', 'virginica'],
#  ['6.8', '3.2', '5.9', '2.3', 'virginica'],
#  ['6.7', '3.3', '5.7', '2.5', 'virginica'],
#  ['6.7', '3.0', '5.2', '2.3', 'virginica'],
#  ['6.3', '2.5', '5.0', '1.9', 'virginica'],
#  ['6.5', '3.0', '5.2', '2.0', 'virginica'],
#  ['6.2', '3.4', '5.4', '2.3', 'virginica'],
#  ['5.9', '3.0', '5.1', '1.8', 'virginica']]

# %%
# The inputs are four floats: sepal length, sepal width, petal length, petal width.
inputs  = np.array(iris)[:,:4].astype(np.float)

# Outputs are initially individual strings: setosa, versicolor or virginica.
outputs = np.array(iris)[:,4]

# Convert the output strings to ints.
outputs_vals, outputs_ints = np.unique(outputs, return_inverse=True)

# %%
# Encode the category integers as binary categorical vairables.
outputs_cats = kr.utils.to_categorical(outputs_ints)

# %%
# Split the input and output data sets into training and test subsets.
inds = np.random.permutation(len(inputs))
train_inds, test_inds = np.array_split(inds, 2)
inputs_train, outputs_train = inputs[train_inds], outputs_cats[train_inds]
inputs_test,  outputs_test  = inputs[test_inds],  outputs_cats[test_inds]

# %%
# Create a neural network.
model = kr.models.Sequential()

# Add an initial layer with 4 input nodes, and a hidden layer with 16 nodes.
model.add(kr.layers.Dense(16, input_shape=(4,)))
# Apply the sigmoid activation function to that layer.
model.add(kr.layers.Activation("sigmoid"))
# Add another layer, connected to the layer with 16 nodes, containing three output nodes.
model.add(kr.layers.Dense(3))
# Use the softmax activation function there.
model.add(kr.layers.Activation("softmax"))

# %%
# Display our Model using the summary function
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 16)                80
# _________________________________________________________________
# activation_4 (Activation)    (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 51
# _________________________________________________________________
# activation_5 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Configure the model for training.
# Uses the adam optimizer and categorical cross entropy as the loss function.
# Add in some extra metrics - accuracy being the only one.
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Fit the model using our training data.
model.fit(inputs_train, outputs_train, epochs=100, batch_size=1, verbose=1)
# Out:
# Epoch 1/100
# 75/75 [==============================] - 2s 3ms/step - loss: 1.5024 - accuracy: 0.3200
# Epoch 2/100
# 75/75 [==============================] - 0s 2ms/step - loss: 1.2510 - accuracy: 0.3200
# Epoch 3/100
# 75/75 [==============================] - 0s 1ms/step - loss: 1.1212 - accuracy: 0.3467
# Epoch 4/100
# 75/75 [==============================] - 0s 2ms/step - loss: 1.0584 - accuracy: 0.5733
# Epoch 5/100
# 75/75 [==============================] - 0s 2ms/step - loss: 1.0239 - accuracy: 0.5467
# Epoch 6/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.9865 - accuracy: 0.7067
# Epoch 7/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.9583 - accuracy: 0.6933
# Epoch 8/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.9262 - accuracy: 0.6933
# Epoch 9/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.8919 - accuracy: 0.6933
# Epoch 10/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.8565 - accuracy: 0.7067
# Epoch 11/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.8205 - accuracy: 0.6933
# Epoch 12/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.7856 - accuracy: 0.6933
# Epoch 13/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7541 - accuracy: 0.7200
# Epoch 14/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7274 - accuracy: 0.6933
# Epoch 15/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7015 - accuracy: 0.7867
# Epoch 16/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.6741 - accuracy: 0.7600
# Epoch 17/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.6518 - accuracy: 0.8667
# Epoch 18/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.6287 - accuracy: 0.7733
# Epoch 19/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.6098 - accuracy: 0.8133
# Epoch 20/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.5968 - accuracy: 0.8267
# Epoch 21/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.5764 - accuracy: 0.8267
# Epoch 22/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.5595 - accuracy: 0.8000
# Epoch 23/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.5477 - accuracy: 0.8533
# Epoch 24/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.5352 - accuracy: 0.9067
# Epoch 25/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.5259 - accuracy: 0.8133
# Epoch 26/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.5101 - accuracy: 0.9467
# Epoch 27/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.4998 - accuracy: 0.8933
# Epoch 28/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.4892 - accuracy: 0.9333
# Epoch 29/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.4796 - accuracy: 0.9733
# Epoch 30/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.4698 - accuracy: 0.9733
# Epoch 31/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.4605 - accuracy: 0.9467
# Epoch 32/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.4524 - accuracy: 0.9467
# Epoch 33/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.4468 - accuracy: 0.9733
# Epoch 34/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.4346 - accuracy: 0.9733
# Epoch 35/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.4269 - accuracy: 0.9733
# Epoch 36/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.4186 - accuracy: 0.9733
# Epoch 37/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.4127 - accuracy: 0.9600
# Epoch 38/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.9733
# Epoch 39/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3974 - accuracy: 0.9733
# Epoch 40/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3869 - accuracy: 0.9733
# Epoch 41/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3809 - accuracy: 0.9733
# Epoch 42/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3776 - accuracy: 0.9600
# Epoch 43/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3712 - accuracy: 0.9600
# Epoch 44/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3605 - accuracy: 0.9733
# Epoch 45/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3501 - accuracy: 0.9867
# Epoch 46/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3431 - accuracy: 0.9733
# Epoch 47/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.9467
# Epoch 48/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3279 - accuracy: 0.9733
# Epoch 49/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3164 - accuracy: 0.9733
# Epoch 50/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3067 - accuracy: 0.9733
# Epoch 51/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3001 - accuracy: 0.9733
# Epoch 52/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2855 - accuracy: 0.9733
# Epoch 53/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2742 - accuracy: 0.9867
# Epoch 54/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2660 - accuracy: 0.9733
# Epoch 55/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.2618 - accuracy: 0.9600
# Epoch 56/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2539 - accuracy: 0.9867
# Epoch 57/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.9600
# Epoch 58/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2426 - accuracy: 0.9733
# Epoch 59/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2368 - accuracy: 0.9733
# Epoch 60/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2293 - accuracy: 0.9867
# Epoch 61/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2224 - accuracy: 0.9733
# Epoch 62/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2177 - accuracy: 0.9733
# Epoch 63/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2149 - accuracy: 0.9733
# Epoch 64/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.2073 - accuracy: 0.9733
# Epoch 65/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.2047 - accuracy: 0.9733
# Epoch 66/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1978 - accuracy: 0.9867
# Epoch 67/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1961 - accuracy: 0.9733
# Epoch 68/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1932 - accuracy: 0.9600
# Epoch 69/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1876 - accuracy: 0.9733
# Epoch 70/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1835 - accuracy: 0.9733
# Epoch 71/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1819 - accuracy: 0.9733
# Epoch 72/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1769 - accuracy: 0.9867
# Epoch 73/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1747 - accuracy: 0.9733
# Epoch 74/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1681 - accuracy: 0.9733
# Epoch 75/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1651 - accuracy: 0.9733
# Epoch 76/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1627 - accuracy: 0.9867
# Epoch 77/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1602 - accuracy: 0.9733
# Epoch 78/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1576 - accuracy: 0.9867
# Epoch 79/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1531 - accuracy: 0.9867
# Epoch 80/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1511 - accuracy: 0.9733
# Epoch 81/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1478 - accuracy: 0.9733
# Epoch 82/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1502 - accuracy: 0.9733
# Epoch 83/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1455 - accuracy: 0.9867
# Epoch 84/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1418 - accuracy: 0.9867
# Epoch 85/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1384 - accuracy: 0.9733
# Epoch 86/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1361 - accuracy: 0.9867
# Epoch 87/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1338 - accuracy: 0.9867
# Epoch 88/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1336 - accuracy: 0.9867
# Epoch 89/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1334 - accuracy: 0.9733
# Epoch 90/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1283 - accuracy: 0.9867
# Epoch 91/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1284 - accuracy: 0.9733
# Epoch 92/100
# 75/75 [==============================] - 0s 969us/step - loss: 0.1256 - accuracy: 0.9733
# Epoch 93/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1229 - accuracy: 0.9867
# Epoch 94/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1212 - accuracy: 0.9867
# Epoch 95/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1207 - accuracy: 0.9867
# Epoch 96/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1197 - accuracy: 0.9733
# Epoch 97/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1176 - accuracy: 0.9867
# Epoch 98/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1149 - accuracy: 0.9733
# Epoch 99/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1169 - accuracy: 0.9733
# Epoch 100/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.1113 - accuracy: 0.9867

# %%
# Evaluate the model using the test data set.
loss, accuracy = model.evaluate(inputs_test, outputs_test, verbose=1)

# Output the accuracy of the model.
print("\n\nLoss: %6.4f\tAccuracy: %6.4f" % (loss, accuracy))
# Out:
# 3/3 [==============================] - 1s 4ms/step - loss: 0.1336 - accuracy: 0.9733
#
#
# Loss: 0.1336	Accuracy: 0.9733

# %%
# Predict the class of a single flower.
prediction = np.around(model.predict(np.expand_dims(inputs_test, axis=0))).astype(np.int)[0]

# print("Actual: %s\tEstimated: %s" % (outputs_test[0].astype(np.int), prediction))
# print("That means it's a %s" % outputs_vals[prediction.astype(np.bool)][0])
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 4) for input KerasTensor(type_spec=TensorSpec(shape=(None, 4), dtype=tf.float32, name='dense_4_input'), name='dense_4_input', description="created by layer 'dense_4_input'"), but it was called on an input with incompatible shape (None, 75, 4).

# %%
# Save the model to a file for later use.
model.save("iris_neural_network.h5")

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
pred = []

# Turning the [0, 0, 0] to actuall names of the flowers for the prediction variable
for item in prediction:
    if item[0] == 1:
        pred.append('Setosa')
    elif item[1] == 1:
        pred.append('Versicolor')
    elif item[2] == 1:
        pred.append('Virginica')

# Converting python list to Numpy array
pred = np.array(pred)

# %%
y_test = []

# Turning the [0, 0, 0] to actuall names of the flowers of output test variable
for item in outputs_test:
    if item[0] == 1.:
        y_test.append('Setosa')
    elif item[1] == 1.:
        y_test.append('Versicolor')
    elif item[2] == 1.:
        y_test.append('Virginica')

# Converting python list to Numpy array
y_test = np.array(y_test)

# %%
confusion_matrix(y_test, pred)
# Out:
# array([[26,  0,  0],
#        [ 0, 24,  2],
#        [ 0,  0, 23]], dtype=int64)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        26
#   Versicolor       1.00      0.92      0.96        26
#    Virginica       0.92      1.00      0.96        23
#
#     accuracy                           0.97        75
#    macro avg       0.97      0.97      0.97        75
# weighted avg       0.98      0.97      0.97        75

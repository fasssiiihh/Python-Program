# %%
import pandas as pd
import numpy as np

# %%
ab = pd.read_excel("population2020.xlsx")

# %%
ab
# Out:
#               Country  Population  Yearly Change  Net Change  Density  \
# 0               China  1440297825         0.0039     5540090      153
# 1               India  1382345085         0.0099    13586631      464
# 2       United States   331341050         0.0059     1937734       36
# 3           Indonesia   274021604         0.0107     2898047      151
# 4            Pakistan   221612785         0.0200     4327022      287
# ..                ...         ...            ...         ...      ...
# 230        Montserrat        4993         0.0006           3       50
# 231  Falkland Islands        3497         0.0305         103        0
# 232              Niue        1628         0.0068          11        6
# 233           Tokelau        1360         0.0127          17      136
# 234          Holy See         801         0.0025           2     2003
#
#      Land Area  Migrants Fert. Rate Med. Age Urban Pop %  World Share
# ...

# %%
ab.isnull()
# Out:
#      Country  Population  Yearly Change  Net Change  Density  Land Area  \
# 0      False       False          False       False    False      False
# 1      False       False          False       False    False      False
# 2      False       False          False       False    False      False
# 3      False       False          False       False    False      False
# 4      False       False          False       False    False      False
# ..       ...         ...            ...         ...      ...        ...
# 230    False       False          False       False    False      False
# 231    False       False          False       False    False      False
# 232    False       False          False       False    False      False
# 233    False       False          False       False    False      False
# 234    False       False          False       False    False      False
#
#      Migrants  Fert. Rate  Med. Age  Urban Pop %  World Share
# ...

# %%
ab.dropna()
# Out:
#                  Country  Population  Yearly Change  Net Change  Density  \
# 0                  China  1440297825         0.0039     5540090      153
# 1                  India  1382345085         0.0099    13586631      464
# 2          United States   331341050         0.0059     1937734       36
# 3              Indonesia   274021604         0.0107     2898047      151
# 4               Pakistan   221612785         0.0200     4327022      287
# ..                   ...         ...            ...         ...      ...
# 196                Aruba      106845         0.0043         452      593
# 197                Tonga      105901         0.0115        1201      147
# 198  U.S. Virgin Islands      104398        -0.0015        -153      298
# 199           Seychelles       98453         0.0062         608      214
# 200  Antigua and Barbuda       98069         0.0084         811      223
#
#      Land Area  Migrants Fert. Rate Med. Age Urban Pop %  World Share
# ...

# %%
ab.head(30)
# Out:
#            Country  Population  Yearly Change  Net Change  Density  Land Area  \
# 0            China  1440297825         0.0039     5540090      153    9388211
# 1            India  1382345085         0.0099    13586631      464    2973190
# 2    United States   331341050         0.0059     1937734       36    9147420
# 3        Indonesia   274021604         0.0107     2898047      151    1811570
# 4         Pakistan   221612785         0.0200     4327022      287     770880
# 5           Brazil   212821986         0.0072     1509890       25    8358140
# 6          Nigeria   206984347         0.0258     5175990      226     910770
# 7       Bangladesh   164972348         0.0101     1643222     1265     130170
# 8           Russia   145945524         0.0004       62206        9   16376870
# 9           Mexico   129166028         0.0106     1357224       66    1943950
# 10           Japan   126407422        -0.0030     -383840      347     364555
# ...

# %%
p=ab.nlargest(3,['Population']) # 3 largest countries with most population 2020 
print(p)
# Out:
#          Country  Population  Yearly Change  Net Change  Density  Land Area  \
# 0          China  1440297825         0.0039     5540090      153    9388211
# 1          India  1382345085         0.0099    13586631      464    2973190
# 2  United States   331341050         0.0059     1937734       36    9147420
#
#    Migrants Fert. Rate Med. Age Urban Pop %  World Share
# 0 -348399.0        1.7       38        0.61       0.1847
# 1 -532687.0        2.2       28        0.35       0.1770
# 2  954806.0        1.8       38        0.83       0.0425

# %%
q=ab.nsmallest(3,["Population"]) # 3 least populated countries
print(q)
# Out:
#       Country  Population  Yearly Change  Net Change  Density  Land Area  \
# 234  Holy See         801         0.0025           2     2003          0
# 233   Tokelau        1360         0.0127          17      136         10
# 232      Niue        1628         0.0068          11        6        260
#
#      Migrants Fert. Rate Med. Age Urban Pop %  World Share
# 234       NaN       N.A.     N.A.        N.A.          0.0
# 233       NaN       N.A.     N.A.           0          0.0
# 232       NaN       N.A.     N.A.        0.46          0.0

# %%
print(plt.pie(p['Population'].values, labels = p['Country'].values))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-e59f4d4eb30c> in <module>
# ----> 1 print(plt.pie(p['Population'].values,labels =p['Country'].values))
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=[9,7])
ab['Population'].value_counts().plot.pie()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-da71fcf65eb0> in <module>
# ----> 1 plt.figure(figsize=[9,7])
#       2 ab['Population'].value_counts().plot.pie()
#       3 plt.show()
#
# NameError: name 'plt' is not defined
